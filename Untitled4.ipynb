# %%
raw_data={'sales_person':['vihan','Aric','Dilini','Saman','Anagi'],
         'jan_Sales':[4,24,31,2,3],
         'Feb_Sales':[25,94,56,78,89],
         'march_sales':[34,56,34,56,89]}
import pandas as pd
df=pd.DataFrame(raw_data)
print(df)
# Out:
#    Feb_Sales  jan_Sales  march_sales sales_person
# 0         25          4           34        vihan
# 1         94         24           56         Aric
# 2         56         31           34       Dilini
# 3         78          2           56        Saman
# 4         89          3           89        Anagi

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


sales_plot=df.plot(
    kind="bar",
    x=df["sales_person"],
    title="January Arrest",
    legend=True)

# %%
fig = sales_plot.get_figure()
fig.savefig('asdf.png')

# %%
import numpy as np
df_hist=pd.DataFrame({'a': np.random.randn(1000)})

# %%
df_hist.plot.hist(alpha = 0.5)

# %%
df_hist.plot.hist(alpha = 0.5,normed=True)

# %%
df_hist2=pd.DataFrame({
    'a':np.random.randn(1000)+3,
    'b':np.random.randn(1000)
})

# %%
df_hist2.plot.hist(alpha=0.5,normed=True,bins=50)

# %%
df_hist3=pd.DataFrame({
    'c':np.random.randn(1000)+3,
    'd':np.random.exponential(1,1000)
})

# %%
df_hist3.plot.hist(alpha=0.5,normed=True,bins=50)

# %%
df_hist4=pd.DataFrame({
    'e':np.random.exponential(1,1000)+3,
    'f':np.random.exponential(1,1000)
})

# %%
df_hist4.plot.hist(alpha=0.5,normed=True,bins=50)

# %%
df_hist2.plot.box()

# %%
import numpy as np
import pandas as pandas
from sklearn import datasets
import statsmodels.api as sm
import math
% matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data=datasets.load_boston()
df=pd.DataFrame(data.data,columns=data.feature_names)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df['MEDV']=data.target

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %%
model=sm.OLS(df.MEDV,sm.add_constant(df.RM))

# %%
sm.add_constant(df.RM)
# Out:
#      const     RM
# 0      1.0  6.575
# 1      1.0  6.421
# 2      1.0  7.185
# 3      1.0  6.998
# 4      1.0  7.147
# 5      1.0  6.430
# 6      1.0  6.012
# 7      1.0  6.172
# 8      1.0  5.631
# 9      1.0  6.004
# 10     1.0  6.377
# 11     1.0  6.009
# 12     1.0  5.889
# 13     1.0  5.949
# 14     1.0  6.096
# 15     1.0  5.834
# 16     1.0  5.935
# 17     1.0  5.990
# 18     1.0  5.456
# 19     1.0  5.727
# 20     1.0  5.570
# 21     1.0  5.965
# 22     1.0  6.142
# 23     1.0  5.813
# 24     1.0  5.924
# 25     1.0  5.599
# 26     1.0  5.813
# 27     1.0  6.047
# 28     1.0  6.495
# 29     1.0  6.674
# ..     ...    ...
# 476    1.0  6.484
# 477    1.0  5.304
# 478    1.0  6.185
# 479    1.0  6.229
# 480    1.0  6.242
# 481    1.0  6.750
# 482    1.0  7.061
# 483    1.0  5.762
# 484    1.0  5.871
# 485    1.0  6.312
# 486    1.0  6.114
# 487    1.0  5.905
# 488    1.0  5.454
# 489    1.0  5.414
# 490    1.0  5.093
# 491    1.0  5.983
# 492    1.0  5.983
# 493    1.0  5.707
# ...

# %%
p=model.fit().params

# %%
p
# Out:
# const   -34.670621
# RM        9.102109
# dtype: float64

# %%
ax=df.plot(x='RM',y='MEDV',kind='scatter')
ax.set_title("Regression Scatter plot")

# %%
ax=df.plot(x='RM',y='MEDV',kind='scatter')
ax.set_title("Regression Scatter plot")

rm_min=math.floor(min(df.RM))
rm_max=math.ceil(max(df.RM))
x=range(rm_min,rm_max)
matplotlib_plot=ax.plot(x,p.const + p.RM*x,color='red')

# %%
import seaborn as sns;sns.set(color_codes=True)
ax1=sns.regplot(x=df.RM,y=df.MEDV,marker='*')

# %%
ax2=sns.residplot(x=df.RM,y=df.MEDV)

# %%
df["AGE_CAT"]=['young' if i<45 else 'old' for i in df.AGE]

# %%
ax3=sns.lmplot(x='RM',y='MEDV',hue='AGE_CAT',data=df)

# %%
ax4=sns.jointplot(x='RM',y='MEDV',data=df,kind='reg')

# %%
sns.pairplot(df,vars=['RM','AGE','MEDV'],hue="AGE_CAT")

# %%
g=sns.PairGrid(df,vars=['RM','AGE','MEDV'],hue="AGE_CAT")
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot,cmap="Blues_d")
g.map_diag(sns.kdeplot,lw=3,legend=False);

# %%
ax=sns.kdeplot(df.AGE,df.MEDV,shade=True)

# %%
# HeatMap

# %matplotlib inline
import seaborn as sns;sns.set()
flights=sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights=flights.pivot('month','year','passengers')
ax=sns.heatmap(flights)

# %%
from IPython.html.widgets import*
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
#Widgets
speed=widgets.RadioButtons(
      options=["high","medium","slow"],
      description='How fast do you run?'

)
speed

# %%
speed.value
# Out:
# 'high'

# %%
import pandas as pd
df=pd.read_csv("IMDB.CSV")

print(df)

import openpyxl
from openpyxl import load_workbook
wb=load_workbook(filename="IMDB.xlsx")
ws=wb['movies']
for row in ws.rows:
    print([cell.value for cell in row])

import csv 

imdb_data=list()
with open("IMDB.csv","rt") as csvfile:
    data=csv.reader(csvfile,delimiter=',')
    for d in data:
        print(d)


imdb_data=list()
with open("IMDB.csv","rt") as csvfile:
    data=csv.reader(csvfile,delimiter=',')
    for d in data:
        print(d)
        break
        
with open("IMDB.csv","rt") as csvfile:
    data=csv.DictReader(csvfile,delimiter=',')
    for d in data:
        imdb_data.append(d)      
import pandas as pd
imdb_df=pd.DataFrame(imdb_data)
print(imdb_df)
# Out:
#                                                   title  year  length  \
# 0                             Adventures of Dollie, The  1908      12
# 1                                          Blaze Orange  2005      16
# 2                           Blessing of Prometheus, The  2000      20
# 3                                                 Bloom  2004       7
# 4                                   Channeling Alphonse  2003      12
# 5                                      Chasing the Edge  2004      15
# 6            Creepees vs. Robot Monster Number Two, The  2004      15
# 7                                       Cupid's Mistake  2001      70
# 8                                     David Nelson Live  2000      42
# 9                                        Dirty Diamonds  2002      10
# 10                                           Dos Blokes  2005       4
# 11                                             Drowning  2001       7
# ...

# %%
df.hist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-eff5294ad023> in <module>()
# ----> 1 df.hist(imdb_df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2117         if not isinstance(column, (list, np.ndarray, Index)):
#    2118             column = [column]
# -> 2119         data = data[column]
#    2120     data = data._get_numeric_data()
#    2121     naxes = len(data.columns)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
# ...
